# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.__version__
# Out:
# '0.13.0'

# %%
pcos = pd.read_excel("PCOS_data_without_infertility.xlsx")
pcos.head(15)
# Out:
#     Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0        1                 1           0          28         44.6
# 1        2                 2           0          36         65.0
# 2        3                 3           1          33         68.8
# 3        4                 4           0          37         65.0
# 4        5                 5           0          25         52.0
# 5        6                 6           0          36         74.1
# 6        7                 7           0          34         64.0
# 7        8                 8           0          33         58.5
# 8        9                 9           0          32         40.0
# 9       10                10           0          36         52.0
# 10      11                11           0          20         71.0
# 11      12                12           0          26         49.0
# 12      13                13           1          25         74.0
# 13      14                14           0          38         50.0
# 14      15                15           0          34         57.3
#
#     Height(Cm)    BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0         152.0  19.3           15                78                22  ...
# 1         161.5   NaN           15                74                20  ...
# 2         165.0   NaN           11                72                18  ...
# 3         148.0   NaN           13                72                20  ...
# 4         161.0   NaN           11                72                18  ...
# 5         165.0   NaN           15                78                28  ...
# 6         156.0   NaN           11                72                18  ...
# 7         159.0   NaN           13                72                20  ...
# 8         158.0   NaN           11                72                18  ...
# 9         150.0   NaN           15                80                20  ...
# 10        163.0   NaN           15                80                20  ...
# 11        160.0   NaN           13                72                20  ...
# 12        152.0   NaN           17                72                18  ...
# 13        152.0   NaN           13                74                20  ...
# 14        162.0   NaN           13                74                22  ...
#
#     Pimples(Y/N)  Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0              0              1.0                  0                  110
# 1              0              0.0                  0                  120
# 2              1              1.0                  0                  120
# 3              0              0.0                  0                  120
# 4              0              0.0                  0                  120
# 5              0              0.0                  0                  110
# 6              0              0.0                  0                  120
# 7              0              0.0                  0                  120
# 8              0              0.0                  0                  120
# 9              0              0.0                  0                  110
# 10             0              0.0                  0                  110
# 11             0              0.0                  0                  120
# 12             1              1.0                  1                  120
# 13             0              0.0                  0                  110
# 14             1              1.0                  0                  120
#
#     BP _Diastolic (mmHg)  Follicle No. (L)  Follicle No. (R)  \
# 0                     80                 3                 3
# 1                     70                 3                 5
# 2                     80                13                15
# 3                     70                 2                 2
# 4                     80                 3                 4
# 5                     70                 9                 6
# 6                     80                 6                 6
# 7                     80                 7                 6
# 8                     80                 5                 7
# 9                     80                 1                 1
# 10                    80                 7                15
# 11                    80                 4                 2
# 12                    80                15                 8
# 13                    70                 3                 3
# 14                    80                 4                 1
#
#    Avg. F size (L) (mm)  Avg. F size (R) (mm)  Endometrium (mm)
# 0                  18.0                  18.0               8.5
# 1                  15.0                  14.0               3.7
# 2                  18.0                  20.0              10.0
# 3                  15.0                  14.0               7.5
# 4                  16.0                  14.0               7.0
# 5                  16.0                  20.0               8.0
# 6                  15.0                  16.0               6.8
# 7                  15.0                  18.0               7.1
# 8                  17.0                  17.0               4.2
# 9                  14.0                  17.0               2.5
# 10                 17.0                  20.0               6.0
# 11                 18.0                  19.0               7.8
# 12                 20.0                  21.0               8.0
# 13                 18.0                  17.0               5.6
# 14                 19.0                  21.0               5.5
#
# [15 rows x 44 columns]

# %%
pcos.isnull().sum()
# Out:
# Sl. No                      0
# Patient File No.            0
# PCOS (Y/N)                  0
#  Age (yrs)                  0
# Weight (Kg)                 0
# Height(Cm)                  0
# BMI                       299
# Blood Group                 0
# Pulse rate(bpm)             0
# RR (breaths/min)            0
# Hb(g/dl)                    0
# Cycle(R/I)                  0
# Cycle length(days)          0
# Marraige Status (Yrs)       1
# Pregnant(Y/N)               0
# No. of aborptions           0
#   I   beta-HCG(mIU/mL)      0
# II    beta-HCG(mIU/mL)      0
# FSH(mIU/mL)                 0
# LH(mIU/mL)                  0
# FSH/LH                    532
# Hip(inch)                   0
# Waist(inch)                 0
# Waist:Hip Ratio           532
# TSH (mIU/L)                 0
# AMH(ng/mL)                  0
# PRL(ng/mL)                  0
# Vit D3 (ng/mL)              0
# PRG(ng/mL)                  0
# RBS(mg/dl)                  0
# Weight gain(Y/N)            0
# hair growth(Y/N)            0
# Skin darkening (Y/N)        0
# Hair loss(Y/N)              0
# Pimples(Y/N)                0
# Fast food (Y/N)             1
# Reg.Exercise(Y/N)           0
# BP _Systolic (mmHg)         0
# BP _Diastolic (mmHg)        0
# Follicle No. (L)            0
# Follicle No. (R)            0
# Avg. F size (L) (mm)        0
# Avg. F size (R) (mm)        0
# Endometrium (mm)            0
# dtype: int64

# %%
pcos = pcos.dropna(axis=1)

# %%
pcos.isnull().sum()
# Out:
# Sl. No                    0
# Patient File No.          0
# PCOS (Y/N)                0
#  Age (yrs)                0
# Weight (Kg)               0
# Height(Cm)                0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Pregnant(Y/N)             0
# No. of aborptions         0
#   I   beta-HCG(mIU/mL)    0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# Hip(inch)                 0
# Waist(inch)               0
# TSH (mIU/L)               0
# AMH(ng/mL)                0
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# Skin darkening (Y/N)      0
# Hair loss(Y/N)            0
# Pimples(Y/N)              0
# Reg.Exercise(Y/N)         0
# BP _Systolic (mmHg)       0
# BP _Diastolic (mmHg)      0
# Follicle No. (L)          0
# Follicle No. (R)          0
# Avg. F size (L) (mm)      0
# Avg. F size (R) (mm)      0
# Endometrium (mm)          0
# dtype: int64

# %%
pcos.head(15)
# Out:
#     Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0        1                 1           0          28         44.6
# 1        2                 2           0          36         65.0
# 2        3                 3           1          33         68.8
# 3        4                 4           0          37         65.0
# 4        5                 5           0          25         52.0
# 5        6                 6           0          36         74.1
# 6        7                 7           0          34         64.0
# 7        8                 8           0          33         58.5
# 8        9                 9           0          32         40.0
# 9       10                10           0          36         52.0
# 10      11                11           0          20         71.0
# 11      12                12           0          26         49.0
# 12      13                13           1          25         74.0
# 13      14                14           0          38         50.0
# 14      15                15           0          34         57.3
#
#     Height(Cm)   Blood Group  Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  \
# 0         152.0           15                78                22     10.48
# 1         161.5           15                74                20     11.70
# 2         165.0           11                72                18     11.80
# 3         148.0           13                72                20     12.00
# 4         161.0           11                72                18     10.00
# 5         165.0           15                78                28     11.20
# 6         156.0           11                72                18     10.90
# 7         159.0           13                72                20     11.00
# 8         158.0           11                72                18     11.80
# 9         150.0           15                80                20     10.00
# 10        163.0           15                80                20     10.00
# 11        160.0           13                72                20      9.50
# 12        152.0           17                72                18     11.70
# 13        152.0           13                74                20     12.10
# 14        162.0           13                74                22     11.70
#
#     ...  Hair loss(Y/N)  Pimples(Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0   ...               0             0                  0                  110
# 1   ...               0             0                  0                  120
# 2   ...               1             1                  0                  120
# 3   ...               0             0                  0                  120
# 4   ...               1             0                  0                  120
# 5   ...               1             0                  0                  110
# 6   ...               0             0                  0                  120
# 7   ...               0             0                  0                  120
# 8   ...               0             0                  0                  120
# 9   ...               0             0                  0                  110
# 10  ...               0             0                  0                  110
# 11  ...               0             0                  0                  120
# 12  ...               1             1                  1                  120
# 13  ...               0             0                  0                  110
# 14  ...               1             1                  0                  120
#
#     BP _Diastolic (mmHg) Follicle No. (L)  Follicle No. (R)  \
# 0                     80                3                 3
# 1                     70                3                 5
# 2                     80               13                15
# 3                     70                2                 2
# 4                     80                3                 4
# 5                     70                9                 6
# 6                     80                6                 6
# 7                     80                7                 6
# 8                     80                5                 7
# 9                     80                1                 1
# 10                    80                7                15
# 11                    80                4                 2
# 12                    80               15                 8
# 13                    70                3                 3
# 14                    80                4                 1
#
#     Avg. F size (L) (mm)  Avg. F size (R) (mm)  Endometrium (mm)
# 0                   18.0                  18.0               8.5
# 1                   15.0                  14.0               3.7
# 2                   18.0                  20.0              10.0
# 3                   15.0                  14.0               7.5
# 4                   16.0                  14.0               7.0
# 5                   16.0                  20.0               8.0
# 6                   15.0                  16.0               6.8
# 7                   15.0                  18.0               7.1
# 8                   17.0                  17.0               4.2
# 9                   14.0                  17.0               2.5
# 10                  17.0                  20.0               6.0
# 11                  18.0                  19.0               7.8
# 12                  20.0                  21.0               8.0
# 13                  18.0                  17.0               5.6
# 14                  19.0                  21.0               5.5
#
# [15 rows x 39 columns]

# %%
pcos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3    Age (yrs)              541 non-null    int64
#  4   Weight (Kg)             541 non-null    float64
#  5   Height(Cm)              541 non-null    float64
#  6   Blood Group             541 non-null    int64
#  7   Pulse rate(bpm)         541 non-null    int64
#  8   RR (breaths/min)        541 non-null    int64
#  9   Hb(g/dl)                541 non-null    float64
#  10  Cycle(R/I)              541 non-null    int64
#  11  Cycle length(days)      541 non-null    int64
#  12  Pregnant(Y/N)           541 non-null    int64
#  13  No. of aborptions       541 non-null    int64
#  14    I   beta-HCG(mIU/mL)  541 non-null    float64
#  15  II    beta-HCG(mIU/mL)  541 non-null    object
#  16  FSH(mIU/mL)             541 non-null    float64
#  17  LH(mIU/mL)              541 non-null    float64
#  18  Hip(inch)               541 non-null    int64
#  19  Waist(inch)             541 non-null    int64
#  20  TSH (mIU/L)             541 non-null    float64
#  21  AMH(ng/mL)              541 non-null    object
#  22  PRL(ng/mL)              541 non-null    float64
#  23  Vit D3 (ng/mL)          541 non-null    float64
#  24  PRG(ng/mL)              541 non-null    float64
#  25  RBS(mg/dl)              541 non-null    float64
#  26  Weight gain(Y/N)        541 non-null    int64
#  27  hair growth(Y/N)        541 non-null    int64
#  28  Skin darkening (Y/N)    541 non-null    int64
#  29  Hair loss(Y/N)          541 non-null    int64
#  30  Pimples(Y/N)            541 non-null    int64
#  31  Reg.Exercise(Y/N)       541 non-null    int64
#  32  BP _Systolic (mmHg)     541 non-null    int64
#  33  BP _Diastolic (mmHg)    541 non-null    int64
#  34  Follicle No. (L)        541 non-null    int64
#  35  Follicle No. (R)        541 non-null    int64
#  36  Avg. F size (L) (mm)    541 non-null    float64
#  37  Avg. F size (R) (mm)    541 non-null    float64
#  38  Endometrium (mm)        541 non-null    float64
# dtypes: float64(14), int64(23), object(2)
# memory usage: 165.0+ KB

# %%
for column in pcos:
    columnSeriesObj = pcos[column]
    pcos[column] = pd.to_numeric(pcos[column],errors="coerce")

# %%
pcos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3    Age (yrs)              541 non-null    int64
#  4   Weight (Kg)             541 non-null    float64
#  5   Height(Cm)              541 non-null    float64
#  6   Blood Group             541 non-null    int64
#  7   Pulse rate(bpm)         541 non-null    int64
#  8   RR (breaths/min)        541 non-null    int64
#  9   Hb(g/dl)                541 non-null    float64
#  10  Cycle(R/I)              541 non-null    int64
#  11  Cycle length(days)      541 non-null    int64
#  12  Pregnant(Y/N)           541 non-null    int64
#  13  No. of aborptions       541 non-null    int64
#  14    I   beta-HCG(mIU/mL)  541 non-null    float64
#  15  II    beta-HCG(mIU/mL)  540 non-null    float64
#  16  FSH(mIU/mL)             541 non-null    float64
#  17  LH(mIU/mL)              541 non-null    float64
#  18  Hip(inch)               541 non-null    int64
#  19  Waist(inch)             541 non-null    int64
#  20  TSH (mIU/L)             541 non-null    float64
#  21  AMH(ng/mL)              540 non-null    float64
#  22  PRL(ng/mL)              541 non-null    float64
#  23  Vit D3 (ng/mL)          541 non-null    float64
#  24  PRG(ng/mL)              541 non-null    float64
#  25  RBS(mg/dl)              541 non-null    float64
#  26  Weight gain(Y/N)        541 non-null    int64
#  27  hair growth(Y/N)        541 non-null    int64
#  28  Skin darkening (Y/N)    541 non-null    int64
#  29  Hair loss(Y/N)          541 non-null    int64
#  30  Pimples(Y/N)            541 non-null    int64
#  31  Reg.Exercise(Y/N)       541 non-null    int64
#  32  BP _Systolic (mmHg)     541 non-null    int64
#  33  BP _Diastolic (mmHg)    541 non-null    int64
#  34  Follicle No. (L)        541 non-null    int64
#  35  Follicle No. (R)        541 non-null    int64
#  36  Avg. F size (L) (mm)    541 non-null    float64
#  37  Avg. F size (R) (mm)    541 non-null    float64
#  38  Endometrium (mm)        541 non-null    float64
# dtypes: float64(16), int64(23)
# memory usage: 165.0 KB

# %%
#Data Visualization
sns.pairplot(pcos.iloc[:,3:7])

# %%
def plot_hist(var):
    plt.figure(figsize=(9,3))
    plt.hist(pcos[var],bins=50)
    plt.xlabel(var)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(var))
    plt.show()

# %%
pcos.columns
# Out:
# Index(['Sl. No', 'Patient File No.', 'PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)',
#        'Height(Cm) ', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)',
#        'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)',
#        'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)',
#        'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)',
#        'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)',
#        'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)',
#        'Follicle No. (L)', 'Follicle No. (R)', 'Avg. F size (L) (mm)',
#        'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %%
numeric_var = [" Age (yrs)","Weight (Kg)","Height(Cm) "]
for n in numeric_var:
    plot_hist(n)

# %%
plt.figure(figsize=(25,25))
correlation = pcos.corr()
sns.heatmap(correlation,annot=True,square=True,fmt=".1f")
# Out:
# <Axes: >

# %%
pcos=pcos.dropna()
pcos.isnull().sum()
# Out:
# Sl. No                    0
# Patient File No.          0
# PCOS (Y/N)                0
#  Age (yrs)                0
# Weight (Kg)               0
# Height(Cm)                0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Pregnant(Y/N)             0
# No. of aborptions         0
#   I   beta-HCG(mIU/mL)    0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# Hip(inch)                 0
# Waist(inch)               0
# TSH (mIU/L)               0
# AMH(ng/mL)                0
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# Skin darkening (Y/N)      0
# Hair loss(Y/N)            0
# Pimples(Y/N)              0
# Reg.Exercise(Y/N)         0
# BP _Systolic (mmHg)       0
# BP _Diastolic (mmHg)      0
# Follicle No. (L)          0
# Follicle No. (R)          0
# Avg. F size (L) (mm)      0
# Avg. F size (R) (mm)      0
# Endometrium (mm)          0
# dtype: int64

# %%
x = pcos.iloc[:,3:].values
y = pcos.iloc[:,2].values

# %%
pcos.isnull().sum()
# Out:
# Sl. No                    0
# Patient File No.          0
# PCOS (Y/N)                0
#  Age (yrs)                0
# Weight (Kg)               0
# Height(Cm)                0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Pregnant(Y/N)             0
# No. of aborptions         0
#   I   beta-HCG(mIU/mL)    0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# Hip(inch)                 0
# Waist(inch)               0
# TSH (mIU/L)               0
# AMH(ng/mL)                0
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# Skin darkening (Y/N)      0
# Hair loss(Y/N)            0
# Pimples(Y/N)              0
# Reg.Exercise(Y/N)         0
# BP _Systolic (mmHg)       0
# BP _Diastolic (mmHg)      0
# Follicle No. (L)          0
# Follicle No. (R)          0
# Avg. F size (L) (mm)      0
# Avg. F size (R) (mm)      0
# Endometrium (mm)          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
def models(x_train,y_train):
    #Logistic Regression
    from sklearn.linear_model import LogisticRegression
    model = LogisticRegression(random_state=0)
    model.fit(x_train,y_train)

    #Random Forest Classifier
    from sklearn.ensemble import RandomForestClassifier
    classifier = RandomForestClassifier(n_estimators=50,criterion="entropy",random_state=0)
    classifier.fit(x_train,y_train)
    
    print("Logistic Regression Accuracy",model.score(x_train,y_train))
    print("Random Forest Classifier Accuracy",classifier.score(x_train,y_train))

    return model,classifier

# %%
m = models(x_train,y_train)
m
# Out:
# Logistic Regression Accuracy 0.9283819628647215
# Random Forest Classifier Accuracy 1.0
# (LogisticRegression(random_state=0),
#  RandomForestClassifier(criterion='entropy', n_estimators=50, random_state=0))

# %%
from sklearn.metrics import confusion_matrix
for i in range(len(m)):
    cm = confusion_matrix(y_test,m[i].predict(x_test))
    tp = cm[1][1]
    tn = cm[0][0]
    fn = cm[1][0]
    fp = cm[0][1]
    print(cm)
    print("testing accuracy = ",(tp+tn)/(tp+tn+fp+fn))
# Out:
# [[98  6]
#  [16 42]]
# testing accuracy =  0.8641975308641975
# [[102   2]
#  [ 16  42]]
# testing accuracy =  0.8888888888888888
